# %%
from langchain_community.document_loaders import CSVLoader

# %%
loader=CSVLoader(
file_path=r"C:\Users\ADMIN\Desktop\Langchain_Tutorial\customers-100.csv"
)
docs = loader.load()
len(docs)
# Out:
# 100

# %%
print(docs[5].metadata)
# Out:
# {'source': 'C:\\Users\\ADMIN\\Desktop\\Langchain_Tutorial\\customers-100.csv', 'row': 5}

# %%
print(docs[5].page_content)
# Out:
# Index: 6
# Customer Id: 2d08FB17EE273F4
# First Name: Aimee
# Last Name: Downs
# Company: Steele Group
# City: Chavezborough
# Country: Bosnia and Herzegovina
# Phone 1: (283)437-3886x88321
# Phone 2: 999-728-1637
# Email: louis27@gilbert.com
# Subscription Date: 2020-02-25
# Website: http://www.berger.net/

# %%
from langchain_community.document_loaders import UnstructuredURLLoader

# %%
loader = UnstructuredURLLoader(
    urls=["https://www.thehindu.com/sci-tech/science/spacex-scrubs-may-21-launch-of-starship-v3-from-texas/article71008947.ece"]
)
docs = loader.load()
len(docs)
# Out:
# 1

# %%
docs[0].metadata
# Out:
# {'source': 'https://www.thehindu.com/sci-tech/science/spacex-scrubs-may-21-launch-of-starship-v3-from-texas/article71008947.ece'}

# %%
print(docs[0].page_content)
# Out:
# You are logged in
#
# Loading...
#
# You don’t have any Active Subscription.
#
# Subscribe now
#
# Subscribed with another email? Logout and Login with that one.
#
# Your active subscription(s)
#
# Account subscription benefits alongside Premium Stories, Editorials, Opinions and more. Unlock these with Subscription
#
# Products you've access to
#
# Additional Subscription Benefits
#
#
#
#
#
# eBooks
#
#
#
#
#
#
#
# Webinars
#
#
#
#
#
#
#
# Newsletters
#
#
#
#
#
#
#
# Games
#
#
#
# Account Settings
#
# Go to My Account
#
#
#
# Bookmarks
#
#
#
# Manage Subscriptions
#
#
#
# Need help with your subscription?
#
#
#
# customersupport@thehindu.co.in
#
#
#
# 1800 102 1878
#
# May 22, 2026e-Paper
#
# The Hindu Logo
#
# Account
#
# eBooks Subscribe
#
# Search
#
# Live Now
#
# News
#
# News India World States Cities
#
# Israel-US strikes on Iran Delimitation Ground Zero Spotlight
#
# newsletterimg
#
# The View From India Looking at World Affairs from the Indian perspective.
#
# SEE ALL NEWSLETTERS
#
# States Cities
#
# Entertainment
#
# Entertainment Art Dance Movies Music Reviews Theatre
#
# newsletterimg
#
# First Day First Show News and reviews from the world of cinema and streaming.
#
# SEE ALL NEWSLETTERS
#
# Opinion
#
# Opinion Editorial Cartoon Columns Comment Interview Lead Letters Open Page Corrections & Clarifications
#
# Business
#
# Business Agri-Business Economy Industry Markets Budget
#
# Sport
#
# Sport Cricket Football Hockey Tennis Athletics Motorsport Races Other Sports
#
# Between Wickets
#
# Technology
#
# Technology Gadgets Internet
#
# newsletterimg
#
# Today's Cache Your download of the top 5 technology stories of the day.
#
# SEE ALL NEWSLETTERS
#
# Science
#
# Science
#
# ISRO Question Corner
#
# newsletterimg
#
# Science For All The weekly newsletter from science writers takes the jargon out of science and puts the fun in!
#
# SEE ALL NEWSLETTERS
#
# Data
#
# Data
#
# Data Point Podcast
#
# newsletterimg
#
# Data Point Decoding the headlines with facts, figures, and numbers
#
# SEE ALL NEWSLETTERS
#
# Education
#
# Education Careers Colleges Schools
#
# newsletterimg
#
# THEdge At the cutting edge of education and careers
#
# SEE ALL NEWSLETTERS
#
# Health
#
# Health
#
# All you need to know about
#
# newsletterimg
#
# Health Matters Ramya Kannan writes to you on getting to good health, and staying there
#
# SEE ALL NEWSLETTERS
#
# Life & Style
#
# Life & Style Fashion Fitness Homes and gardens Luxury Motoring Travel
#
# Society
#
# Society Faith History & Culture
#
# newsletterimg
#
# Gender Agenda Stories from beyond the binary.
#
# SEE ALL NEWSLETTERS
#
# Books
#
# Books Authors Reviews
#
# Literary Review
#
# newsletterimg
#
# The Hindu On Books Books of the week, reviews, excerpts, new titles and features.
#
# SEE ALL NEWSLETTERS
#
# Children
#
# Elections
#
# Elections Assam Kerala Puducherry Tamil Nadu West Bengal
#
# Food
#
# Food Dining Features Guides Recipes
#
# Environment Real Estate Agriculture
#
# Brandhub
#
# Brandhub PR Release
#
# The Hindu Best Places to Work
#
# May 22, 2026e-Paper
#
# Search for topics, people, articles...
#
# India Elections World Sport Data Health Opinion Science Entertainment Premium
#
# Videos Podcast Photos Visual Stories Specials TH Explains
#
# eBooks TH Games Newsletter Lit For Life The Huddle
#
# The Hindu Logo
#
# SpaceX scrubs May 21 launch of Starship V3 from Texas
#
# Starship V3, uncrewed and ​featuring dozens of upgrades tailored for rapid ⁠Starlink satellite launches and NASA moon missions, was to be a key test for the vehicle following months of testing delays
#
# Published - May 22, 2026 05:56 am IST
#
# Reuters
#
# SEE ALL Remove
#
# The sun rises before preparations continue at launch pad 2 for the 12th test flight of SpaceX's Starship spacecraft and the Super Heavy booster in Starbase, Texas, U.S., May 18, 2026. | Photo Credit: Reuters
#
# SpaceX on Thursday (May 21, 2026) scrubbed the launch of ​its 12th Starship rocket from Texas and said it ‌will attempt it again on Friday (May 22, 2026).
#
# Starship V3, uncrewed and ​featuring dozens of upgrades tailored for rapid ⁠Starlink satellite launches and NASA moon missions, was to be a key test for the vehicle following months of testing delays. ‌It is also poised to affect investor confidence ahead of what might be the biggest ‌initial public offering in history.
#
# Elon Musk’s SpaceX had spent ‌months ⁠redesigning Starship after a streak of failures last ⁠year, culminating in the V3 design that was meant to launch on Thursday (May 21, 2026).
#
# SpaceX called off Thursday’s (May 21, 2026) launch seconds before its planned liftoff, ​after multiple pauses to ‌the countdown triggered by fuel temperature and pressure readings. Musk said on X that the a hydraulic pin on one of the launch tower’s giant mechanical arms did ‌not retract as designed.
#
# “If that can be ​fixed tonight, there will be another launch attempt tomorrow at 5:30 CT,” Elon Musk said ⁠of the faulty arm.
#
# The fully reusable Starship, which SpaceX has spent more than $15 billion developing, is key to ‌Musk’s goals of cutting launch costs, expanding his Starlink satellite business and pursuing ambitions ranging from deep-space exploration to orbital data centers — all factored in to his targeted $1.75 trillion IPO valuation.
#
# Before the launch attempt on Thursday (May 21, 2026), Mr. Musk sought to temper expectations in case of failure, saying, “There ‌is a large pipeline of V3 ships and boosters in the ​factory.” He said a failure would not affect the cadence of future Starship test launches “by more ⁠than a month or so.”
#
# SpaceX’s engineering culture, considered more risk-tolerant than ⁠many of the aerospace industry’s more established players, is built on a flight-testing strategy that pushes ‌newly developed spacecraft to the point of failure, then fine-tunes improvements through frequent repetition.
#
# Published - May 22, 2026 05:56 am IST
#
# Copy link
#
# Email
#
# Facebook
#
# Twitter
#
# Telegram
#
# LinkedIn
#
# WhatsApp
#
# Reddit
#
# SEE ALL Remove
#
# Google Preferred Source
#
# Related Topics
#
# space programme / science (general)
#
# 0 / 0
#
# Return to frontpage
#
# The Hindu
#
# About Us Code of Editorial Values News Archive Sitemap Print Subscription Digital Subscription Subscribe to Newsletters Rss Feeds Readers Editor-Terms of Reference Authors & Contributors Gift Front page
#
# Contact us
#
# Contact Us Social Media Advertise With Us
#
# Group News Sites
#
# Business Line BL on Campus Sportstar Frontline இந்து தமிழ் திசை The Hindu Centre Young World Club The Hindu ePaper Business Line ePaper TH Games
#
# Other Products
#
# STEP Images Classifieds - Print Bookstore & Special Publications
#
# Popular Sections
#
# Elections Latest News National News International News Videos Life & Style Food Podcast Showcase Visual Story
#
# Opinion
#
# Editorial Columns Comment Cartoon Letters Interview Lead
#
# Business
#
# Agri-Business Industry Economy Markets Budget
#
# Sport
#
# Cricket Football Hockey Tennis Athletics Motorsport Races Other Sports
#
# Sci-Tech
#
# Science Technology Health Agriculture Environment Gadgets Internet
#
# States
#
# Andhra Pradesh Karnataka Kerala Tamil Nadu Telangana
#
# Cities
#
# Bengaluru Chennai Coimbatore Delhi Hyderabad Kochi Kolkata Kozhikode Madurai Mangaluru Mumbai Puducherry Thiruvananthapuram Tiruchirapalli Vijayawada Visakhapatnam
#
# Trending on The Hindu
#
# News Tamil Nadu Assembly election 2026 LIVE West Bengal Elections 2026 Phase 1 Voting LIVE Tamil Nadu elections: Delays, limited bus services affect polling day travel across State Why is the Strait of Hormuz critical to global energy flows? | Explained What changed in Hungary’s election? | Explained What the Trans Amendment does to a student Why are saturated fats bad for the heart but unsaturated fats are okay? Live news
#
# Trending on Group sites
#
# Stock Market Live Updates SRH vs DC Live Score IND vs ENG Test Series Full Results TH Games Gold Rate Today Silver Rate Today Arvind Kejriwal Exclusive Interview Editor’s Note: Putting Muslims in their place? Frontline Current Issue
#
# Latest News
#
# For pregnant women in Chennai’s tenements, summer offers no escape
#
# Google’s new ‘Information Agents’ are a privacy and web infrastructure problem
#
# U.S. pins hopes on mediator Pakistan in push to end Iran war
#
# RO systems should be maintained properly to be effective, says study
#
# Structural problem: Poor funding for education makes NEP just tall talk
#
# How does the Gaganyaan’s life-support system operate?
#
# Patterns from Gujarat’s 2026 local body elections
#
# Jazz, cocktails and duck roast: Koshy’s hosts a nostalgic supper club in Bengaluru
#
# Is a heatwave really a wave of heat?
#
# Should the rupee be left to depreciate?
#
# Terms of Use Privacy Policy
#
# Copyright© 2026, THG PUBLISHING PVT LTD. or its affiliated companies. All rights reserved.
#
# BACK TO TOP
#
# The Hindu
#
# Sign in to unlock member-only benefits!
#
# Access 10 free stories every month
#
# Save stories to read later
#
# Access to comment on every story
#
# Sign-up/manage your newsletter subscriptions with a single click
#
# Get notified by email for early access to discounts & offers on our products
#
# Sign in
#
# Looks like you are already logged in from more than 5 devices!
#
# To continue logging in, remove at least one device from the below list
#
# Terms & conditions | Institutional Subscriber
#
# Comments
#
# Comments have to be in English, and in full sentences. They cannot be abusive or personal. Please abide by our community guidelines for posting your comments.
#
# We have migrated to a new commenting platform. If you are already a registered user of The Hindu and logged in, you may continue to engage with our articles. If you do not have an account please register and login to post comments. Users can access their older comments by logging into their accounts on Vuukle.

# %%
# !pip install -U langchain-text-splitters
# Out:
# Requirement already satisfied: langchain-text-splitters in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (1.1.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.31 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from langchain-text-splitters) (1.4.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.8.5)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.13.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.1.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.46.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.4.2)
# Requirement already satisfied: anyio in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.13.0)
# Requirement already satisfied: certifi in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.0.9)
# Requirement already satisfied: idna in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.5.0)
# [notice] A new release of pip available: 22.3 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_text_splitters import CharacterTextSplitter

# %%
text ='''The sun rises before preparations continue at launch pad 2 for the 12th test flight of SpaceX's Starship spacecraft and the Super Heavy booster in Starbase, Texas, U.S., May 18, 2026. | Photo Credit: Reuters

SpaceX on Thursday (May 21, 2026) scrubbed the launch of ​its 12th Starship rocket from Texas and said it ‌will attempt it again on Friday (May 22, 2026).

Starship V3, uncrewed and ​featuring dozens of upgrades tailored for rapid ⁠Starlink satellite launches and NASA moon missions, was to be a key test for the vehicle following months of testing delays. ‌It is also poised to affect investor confidence ahead of what might be the biggest ‌initial public offering in history.

Elon Musk’s SpaceX had spent ‌months ⁠redesigning Starship after a streak of failures last ⁠year, culminating in the V3 design that was meant to launch on Thursday (May 21, 2026).

SpaceX called off Thursday’s (May 21, 2026) launch seconds before its planned liftoff, ​after multiple pauses to ‌the countdown triggered by fuel temperature and pressure readings. Musk said on X that the a hydraulic pin on one of the launch tower’s giant mechanical arms did ‌not retract as designed.
'''

# %%
splitter = CharacterTextSplitter(
    separator ="\n",
    chunk_size=200,
    chunk_overlap=10
)
chunks=splitter.split_text(text)
# Out:
# Created a chunk of size 207, which is longer than the specified 200
# Created a chunk of size 321, which is longer than the specified 200

# %%
len(chunks)
# Out:
# 5

# %%
len(chunks[0]),len(chunks[1])
# Out:
# (207, 154)

# %%
print(text)
# Out:
# The sun rises before preparations continue at launch pad 2 for the 12th test flight of SpaceX's Starship spacecraft and the Super Heavy booster in Starbase, Texas, U.S., May 18, 2026. | Photo Credit: Reuters
#
# SpaceX on Thursday (May 21, 2026) scrubbed the launch of ​its 12th Starship rocket from Texas and said it ‌will attempt it again on Friday (May 22, 2026).
#
# Starship V3, uncrewed and ​featuring dozens of upgrades tailored for rapid ⁠Starlink satellite launches and NASA moon missions, was to be a key test for the vehicle following months of testing delays. ‌It is also poised to affect investor confidence ahead of what might be the biggest ‌initial public offering in history.
#
# Elon Musk’s SpaceX had spent ‌months ⁠redesigning Starship after a streak of failures last ⁠year, culminating in the V3 design that was meant to launch on Thursday (May 21, 2026).
#
# SpaceX called off Thursday’s (May 21, 2026) launch seconds before its planned liftoff, ​after multiple pauses to ‌the countdown triggered by fuel temperature and pressure readings. Musk said on X that the a hydraulic pin on one of the launch tower’s giant mechanical arms did ‌not retract as designed.

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
r_splitter = RecursiveCharacterTextSplitter(
    separators=["\n\n","\n"," "],
    chunk_size=200,
    chunk_overlap=30,
    length_function=len
)

# %%
chunks = r_splitter.split_text(text)
len(chunks)
# Out:
# 8

# %%
for chunk in chunks:
    print(len(chunk))
# Out:
# 199
# 37
# 154
# 192
# 156
# 179
# 195
# 130

# %%
print(chunks[4])
# Out:
# following months of testing delays. ‌It is also poised to affect investor confidence ahead of what might be the biggest ‌initial public offering in history.

# %%
first_split = text.split("\n\n")[0]
first_split
# Out:
# "The sun rises before preparations continue at launch pad 2 for the 12th test flight of SpaceX's Starship spacecraft and the Super Heavy booster in Starbase, Texas, U.S., May 18, 2026. | Photo Credit: Reuters"

# %%
second_split = text.split("\n\n")[0]
second_split
# Out:
# "The sun rises before preparations continue at launch pad 2 for the 12th test flight of SpaceX's Starship spacecraft and the Super Heavy booster in Starbase, Texas, U.S., May 18, 2026. | Photo Credit: Reuters"

# %%
third_split = text.split(" ")[0]
third_split
# Out:
# 'The'
